# %% [markdown]
# # Good and Bad Controls, Dot files
#
# Main Reference:
#
# * <a href=https://ftp.cs.ucla.edu/pub/stat_ser/r493.pdf>A Crash Course in Good and Bad Controls</a>,
# by Carlos Cinelli, Andrew Forney and Judea Pearl
#
# In this notebook, we plot the 18
# & 1/2 DAGs from the above paper (18 are given unique numbers and the nineteeth
# one is called 11u because it adds a node U to DAG 11).
#
# Control nodes are colored pink, unobserved nodes have a dashed oval.
#
# The dot code was drawn ahead of time, and checked for bugs, using the
# following very useful, online, interactive renderer of dot code:
#
# https://dreampuf.github.io/GraphvizOnline/

# %%
# this makes sure it starts looking for things from the JudeasRx folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\JudeasRx

# %%
import graphviz as gv
from IPython.display import display, Image


def draw(path):
    s = gv.Source.from_file(path)
    #display(s)
    x=s.render("jupyter_notebooks/testing", format='jpeg',view=False)
    display(Image(x))

# %%
draw("dot_lib/good_bad_trols_G1.dot")

# %%
draw("dot_lib/good_bad_trols_G2.dot")

# %%
draw("dot_lib/good_bad_trols_G3.dot")

# %%
draw("dot_lib/good_bad_trols_G4.dot")

# %%
draw("dot_lib/good_bad_trols_G5.dot")

# %%
draw("dot_lib/good_bad_trols_G6.dot")

# %%
draw("dot_lib/good_bad_trols_G7.dot")

# %%
draw("dot_lib/good_bad_trols_G8.dot")

# %%
draw("dot_lib/good_bad_trols_G9.dot")

# %%
draw("dot_lib/good_bad_trols_G10.dot")

# %%
draw("dot_lib/good_bad_trols_G11.dot")

# %%
draw("dot_lib/good_bad_trols_G11u.dot")

# %%
draw("dot_lib/good_bad_trols_G12.dot")

# %%
draw("dot_lib/good_bad_trols_G13.dot")

# %%
draw("dot_lib/good_bad_trols_G14.dot")

# %%
draw("dot_lib/good_bad_trols_G15.dot")

# %%
draw("dot_lib/good_bad_trols_G16.dot")

# %%
draw("dot_lib/good_bad_trols_G17.dot")

# %%
draw("dot_lib/good_bad_trols_G18.dot")
