# %% [markdown]
# # Good and Bad Controls, drawing their Dot files
#
# Main Reference:
#
# * <a href=https://ftp.cs.ucla.edu/pub/stat_ser/r493.pdf>A Crash Course in Good and Bad Controls</a>,
# by Carlos Cinelli, Andrew Forney and Judea Pearl
#
# In this notebook, we plot every single of the 20 DAGs in the above paper (18 are given unique numbers from 1 to 18, plus there are
# two variations,  7up and 11u).( 7u is shown last because it was added belatedly to a second version of the paper)
#
# Control nodes are colored pink, unobserved nodes have a dashed oval contour.
#
# The dot code was drawn ahead of time, and checked for bugs, using the
# following very useful, online, interactive renderer of dot code:
#
# https://dreampuf.github.io/GraphvizOnline/

# %%
# this makes sure it starts looking for things from the JudeasRx folder down.
import os
import sys
os.chdir('../')
sys.path.insert(0,os.getcwd())
print(os.getcwd())
# Out:
# C:\Users\rrtuc\Desktop\backed-up\python-projects\JudeasRx

# %%
from DotTool import *

# %%
DotTool.draw("dot_atlas/good_bad_trols_G1.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G2.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G3.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G4.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G5.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G6.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G7.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G8.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G9.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G10.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G11.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G11u.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G12.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G13.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G14.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G15.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G16.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G17.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G18.dot")

# %%
DotTool.draw("dot_atlas/good_bad_trols_G7up.dot")
